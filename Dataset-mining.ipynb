# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
# !pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-0c77e5e7-7c4c-4341-adf8-4404a5729ae3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c77e5e7-7c4c-4341-adf8-4404a5729ae3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"harshkumarsingh","key":"fbcba65f4a91828b1d2d1b5235832b65"}'}

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
 ! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d christofel04/fire-detection-dataset
# !kaggle datasets download -d tharakan684/urecamain
# !kaggle datasets download -d ritupande/fire-detection-from-cctv
# !kaggle datasets download -d atulyakumar98/test-dataset
# Out:
# ...
#  99% 426M/431M [00:03<00:00, 142MB/s]
# 100% 431M/431M [00:03<00:00, 146MB/s]
# ...
#  93% 90.0M/96.8M [00:00<00:00, 128MB/s]
# 100% 96.8M/96.8M [00:00<00:00, 124MB/s]
# ...
#  98% 319M/325M [00:02<00:00, 131MB/s]
# 100% 325M/325M [00:02<00:00, 137MB/s]
# ...
#  90% 119M/132M [00:01<00:00, 126MB/s]
# 100% 132M/132M [00:01<00:00, 118MB/s]

# %%
# !unzip fire-detection-dataset.zip
# !unzip urecamain.zip
# !unzip fire-detection-from-cctv.zip
# !unzip test-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Train/Non-Fire/road_night496.jpg
#   inflating: Train/Non-Fire/road_night497.jpg
#   inflating: Train/Non-Fire/road_night498.jpg
#   inflating: Train/Non-Fire/road_night499.jpg
#   inflating: Train/Non-Fire/road_night500.jpg
#   inflating: Train/Non-Fire/road_night501.jpg
#   inflating: Train/Non-Fire/road_night502.jpg
#   inflating: Train/Non-Fire/road_night503.jpg
#   inflating: Train/Non-Fire/road_night504.jpg
#   inflating: Train/Non-Fire/road_night505.jpg
#   inflating: Train/Non-Fire/road_night506.jpg
#   inflating: Train/Non-Fire/road_night507.jpg
#   inflating: Train/Non-Fire/road_night508.jpg
#   inflating: Train/Non-Fire/road_night509.jpg
#   inflating: Train/Non-Fire/road_night510.jpg
#   inflating: Train/Non-Fire/road_night511.jpg
#   inflating: Train/Non-Fire/road_night512.jpg
#   inflating: Train/Non-Fire/road_night513.jpg
#   inflating: Train/Non-Fire/road_night514.jpg
# ...

# %%
# %cp -a /content/drive/MyDrive/data/img_data/train/fire/. /content/drive/MyDrive/Train/Fire
# %cp -a /content/drive/MyDrive/data/img_data/train/default/. /content/drive/MyDrive/Train/Neutral
# %cp -a /content/drive/MyDrive/data/img_data/train/smoke/. /content/drive/MyDrive/Train/Smoke
# %cp -a /content/drive/MyDrive/data/img_data/test/fire/. /content/drive/MyDrive/Test/Fire
# %cp -a /content/drive/MyDrive/data/img_data/test/default/. /content/drive/MyDrive/Test/Neutral
# %cp -a /content/drive/MyDrive/data/img_data/test/smoke/. /content/drive/MyDrive/Test/Smoke

# %%
# %cp -a /content/drive/MyDrive/Fire\ Dataset\ PCD/Train/Fire/. /content/drive/MyDrive/Train/Fire
# %cp -a /content/drive/MyDrive/Fire\ Dataset\ PCD/Train/Neutral/. /content/drive/MyDrive/Train/Neutral
# %cp -a /content/drive/MyDrive/Fire\ Dataset\ PCD/Test/Fire/. /content/drive/MyDrive/Test/Fire
# %cp -a /content/drive/MyDrive/Fire\ Dataset\ PCD/Test/Neutral/. /content/drive/MyDrive/Test/Neutral

# %%
# %cp -a /content/drive/MyDrive/Fire-Detection/0/. /content/drive/MyDrive/Train/Neutral
# %cp -a /content/drive/MyDrive/Fire-Detection/1/. /content/drive/MyDrive/Train/Fire

# %%
# %cp -a /content/drive/MyDrive/Vali/Fire/. /content/drive/MyDrive/Train/Fire
# %cp -a /content/drive/MyDrive/Vali/Non-Fire/. /content/drive/MyDrive/Train/Neutral

# %%
# %cp -a /content/drive/MyDrive/Train/Non-Fire/. /content/drive/MyDrive/Train/Neutral
# %cp -a /content/drive/MyDrive/Test/Non-Fire/. /content/drive/MyDrive/Test/Neutral
